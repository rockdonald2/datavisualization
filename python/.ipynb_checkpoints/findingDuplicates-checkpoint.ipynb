# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient

# %%
# alapértelmezett beállításokkal, csupán az adatbázisnév tetszőleges
def get_mongo_database(
    db_name, host="localhost", port=27017, username=None, password=None
):
    """ Elérjük a db_name-mel hivatkozott adatbázist MongoDB-ről, hitelesítő adatokkal vagy azok nélkül """

    if username and password:
        mongo_uri = "mongodb://{}:{}@{}/{}".format(username, password, host, db_name)
        # URI = uniform resource identifier
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)

    return conn[
        db_name
    ]  # itt már a második féle jelölést használjuk az adatbázis eléréséhez


def mongo_to_dataframe(
    db_name,
    collection,
    query={},
    host="localhost",
    port=27017,
    username=None,
    password=None,
    no_id=True,
):
    """ Létrehoz egy DataFrame-t egy MongoDB collection-ból """

    db = get_mongo_database(db_name, host, port, username, password)

    # megkeresi a collection-ból a lekérdezés szerinti elemeket
    cursor = db[collection].find(query)

    df = pd.DataFrame(list(cursor))

    # amennyiben azt szeretnénk, hogy törölje ki a MongoDB által hozzáadott id-t
    if no_id:
        del df["_id"]

    return df


# alapvetően, a removeexisting kitörli, ha már létezik,
# a skipifexists, átugorja, ha már létezik,
# de a forceupdate esetén vagy hozzáfűzi, vagy törli és újratölti a removeexisting függvényében
def dataframe_to_mongo(
    df,
    db_name,
    collection,
    host="localhost",
    port=27017,
    username=None,
    password=None,
    removeexisting=True,
    skipifexists=False,
    forceupdate=False,
):
    """ Lement egy DataFrame-t egy MongoDB collection-be """
    db = get_mongo_database(db_name, host, port, username, password)

    if (skipifexists and not forceupdate) and (collection in db.list_collection_names()):
        return

    if (collection in db.list_collection_names()) and removeexisting:
        db[collection].drop()

    records = df.to_dict(orient="records")

    db[collection].insert_many(records)

# %%
def dataframe_mongo_compatible(df):
    # a MongoDB-n való tárolás miatt vissza kell alakítani object-é az oszlopot, és NaN-ra állítani a NaT-okat,
    # mert másképp nem engedi feltölteni, ValueError miatt
    df.date_of_death = df.date_of_death.astype(object).where(df.date_of_death.notnull(), np.nan)

    return df

def dataframe_reverse_compatible(df):
    # visszalakítjuk datetime objektummá az oszlopot
    df.date_of_death = pd.to_datetime(df.date_of_death)

    return df

# %%
# lekérjük a Nobel-adatsorunkat az adatbázisunkból
df = mongo_to_dataframe('nobel_prize', 'winners_cleaned')

# lekérjük az 1996-ban győzött egyéneket
df[df.year == 1996].count() # 14 győztes, 1-el több, mint kellene
df[df.year == 1996] # meg is van, Rolf Zinkernagel kétszer szerepel
# Wikipédia hiba miatt nem törlődött, hiszen nem volt megcsillagozva a neve, jelölve a born_in és country ellentétet

# töröljük a svájci Zinkernagel-t, hiszen inkább mondható Ausztrálnak, mint svájcinak
df = df[~(df.name == 'Rolf M. Zinkernagel')]
df[df.year == 1996].count() # 13 győztes

# df.info() # 926 győztes, még mindig 7-el több, mint kellene

df = df.drop_duplicates(['name', 'year']) # nincsenek tökéletes duplikátumok névbeli elírás lehet

# valami nincs rendben 2000-el sem, hiszen több győztes van, mint kellene, és 2001-el sem
df[df.year == 2000].count() # megfelelő 13 győztes
df[df.year == 2001].count() # 1-el kevesebb, mint kellene, minden rendben, hiszen a 15-ik győztes szervezet, és nem egyén

df[df.gender == 'female'].count() # rendben van, 54 kell legyen
df.describe(include=['object']) # 922 unique név van, ami túl sok, 3-al több, mint kellene
# Out:
#                                             link         name  \
# count                                        926          926
# unique                                       922          922
# top     http://en.wikipedia.org/wiki/Marie_Curie  Marie Curie
# freq                                           2            2
#
#                       category        country                           text  \
# count                      926            926                            926
# unique                       6             59                            926
# top     Physiology or Medicine  United States  Pyotr Kapitsa , Physics, 1978
# freq                       221            363                              1
#
#        place_of_birth place_of_death gender
# count             926            633    926
# unique            648            334      2
# top     New York City      Cambridge   male
# freq               34             35    872

# %%
# következő taktika arra, hogy megtaláljuk a 3 többlet győztest, hogy kategóriánkként nézzük meg melyikből van több
df[df.category == 'Physics'].count() # 1-el több, mint kellene
df[df.category == 'Chemistry'].count() # 1-el több, mint kellene
df[df.category == 'Physiology or Medicine'].count() # 2-vel több, mint kellene
df[df.category == 'Literature'].count() # 1-el kevesebb, mint kellene
df[df.category == 'Peace'].count() # rendben van
df[df.category == 'Economics'].count() # rendben van

# tehát, megtudtuk azt, hogy fizikából és kémiából 1-el több, orvostanból 2-vel több van, míg irodalomból valaki hiányzik
# Out:
# link              84
# name              84
# year              84
# category          84
# country           84
# text              84
# date_of_birth     84
# date_of_death     43
# place_of_birth    84
# place_of_death    43
# gender            84
# award_age         84
# dtype: int64

# %%
df[(df.category == 'Literature') & (df.year == 1974)]
# Out:
#                                              link             name  year  \
# 537   http://en.wikipedia.org/wiki/Eyvind_Johnson   Eyvind Johnson  1974
# 540  http://en.wikipedia.org/wiki/Harry_Martinson  Harry Martinson  1974
#
#        category country                                text date_of_birth  \
# 537  Literature  Sweden   Eyvind Johnson , Literature, 1974    1900-07-29
# 540  Literature  Sweden  Harry Martinson , Literature, 1974    1904-05-06
#
#     date_of_death place_of_birth place_of_death gender  award_age
# 537    1976-08-25          Boden      Stockholm   male         74
# 540    1978-02-11       Blekinge      Stockholm   male         70

# %%
df[df.name == 'Olga Tokarczuk']
# Out:
#                                             link            name  year  \
# 594  http://en.wikipedia.org/wiki/Olga_Tokarczuk  Olga Tokarczuk  2018
#
#        category country                               text date_of_birth  \
# 594  Literature  Poland  Olga Tokarczuk , Literature, 2018    1962-01-29
#
#     date_of_death place_of_birth place_of_death  gender  award_age
# 594           NaT       Sulechów            NaN  female         56

# %%
# következő technika, hogy országok szerint ellenőrízzük le
# amerikai irodalmárokból hiányzik 1
df[(df.category == 'Literature') & (df.country == 'United States')].count()
df[(df.category == 'Literature') & (df.country == 'United States')].sort_values(by=['year'])
# végül kiderült Amerikából sem hiányzik, csak Lengyelországba van bejegyezve a nyertes
# Out:
#                                                   link                   name  \
# 52         http://en.wikipedia.org/wiki/Sinclair_Lewis         Sinclair Lewis
# 59       http://en.wikipedia.org/wiki/Eugene_O%27Neill         Eugene O'Neill
# 58          http://en.wikipedia.org/wiki/Pearl_S._Buck          Pearl S. Buck
# 66       http://en.wikipedia.org/wiki/William_Faulkner       William Faulkner
# 90       http://en.wikipedia.org/wiki/Ernest_Hemingway       Ernest Hemingway
# 33         http://en.wikipedia.org/wiki/John_Steinbeck         John Steinbeck
# 163           http://en.wikipedia.org/wiki/Saul_Bellow            Saul Bellow
# 139  http://en.wikipedia.org/wiki/Isaac_Bashevis_Si...  Isaac Bashevis Singer
# 205        http://en.wikipedia.org/wiki/Joseph_Brodsky         Joseph Brodsky
# 232         http://en.wikipedia.org/wiki/Toni_Morrison          Toni Morrison
# 360             http://en.wikipedia.org/wiki/Bob_Dylan              Bob Dylan
#
#      year    category        country  \
# 52   1930  Literature  United States
# 59   1936  Literature  United States
# 58   1938  Literature  United States
# 66   1949  Literature  United States
# 90   1954  Literature  United States
# 33   1962  Literature  United States
# 163  1976  Literature  United States
# 139  1978  Literature  United States
# 205  1987  Literature  United States
# 232  1993  Literature  United States
# 360  2016  Literature  United States
#
#                                                   text date_of_birth  \
# 52                   Sinclair Lewis , Literature, 1930    1885-02-07
# 59                   Eugene O'Neill , Literature, 1936    1888-10-16
# 58                    Pearl S. Buck , Literature, 1938    1892-06-26
# 66                 William Faulkner , Literature, 1949    1897-09-25
# 90                 Ernest Hemingway , Literature, 1954    1899-07-21
# 33                   John Steinbeck , Literature, 1962    1902-02-27
# 163   Saul Bellow ,  born in Canada , Literature, 1976    1915-06-10
# 139  Isaac Bashevis Singer ,  born in then Russian ...    1902-11-21
# 205  Joseph Brodsky ,  born in Russia , Literature,...    1940-05-24
# 232                   Toni Morrison , Literature, 1993    1931-02-18
# 360                       Bob Dylan , Literature, 2016    1941-05-24
#
#     date_of_death    place_of_birth place_of_death  gender  award_age
# 52     1951-01-10       Sauk Centre           Rome    male         45
# 59     1953-11-27     New York City         Boston    male         48
# 58     1973-03-06         Hillsboro          Danby  female         46
# 66     1962-07-06        New Albany        Byhalia    male         52
# 90     1961-07-02          Oak Park        Ketchum    male         55
# 33     1968-12-20           Salinas         Harlem    male         60
# 163    2005-04-05           Lachine      Brookline    male         61
# 139    1991-07-24           Leoncin          Miami    male         76
# 205    1996-01-28  Saint Petersburg       Brooklyn    male         47
# 232    2019-08-05            Lorain      The Bronx  female         62
# 360           NaT            Duluth            NaN    male         75

# %%
count = 0

for i in range(0, 10):
    year = 1960 + i
    count = count + int(df[(df.category == 'Literature') & (df.year == year) & (df.gender == 'male')].count().link)

print(count)

# kiderült 1960-1969 között hiányzik egy
# Out:
# 9

# %%
df[(df.category == 'Literature') & (df.year == 1913)]
# Out:
#                                                  link                 name  \
# 695  http://en.wikipedia.org/wiki/Rabindranath_Tagore  Rabindranath Tagore
#
#      year    category country                                    text  \
# 695  1913  Literature   India  Rabindranath Tagore , Literature, 1913
#
#     date_of_birth date_of_death place_of_birth place_of_death gender  \
# 695    1861-05-07    1941-08-07        Kolkata        Kolkata   male
#
#      award_age
# 695         52

# %%
df[(df.category == 'Literature') & (df.year >= 1960) & (df.year <= 1969)].sort_values(by=['year'])
# Out:
#                                                   link                   name  \
# 778      http://en.wikipedia.org/wiki/Saint-John_Perse       Saint-John Perse
# 33         http://en.wikipedia.org/wiki/John_Steinbeck         John Steinbeck
# 724       http://en.wikipedia.org/wiki/Giorgos_Seferis        Giorgos Seferis
# 777      http://en.wikipedia.org/wiki/Jean-Paul_Sartre       Jean-Paul Sartre
# 577     http://en.wikipedia.org/wiki/Mikhail_Sholokhov      Mikhail Sholokhov
# 543           http://en.wikipedia.org/wiki/Nelly_Sachs            Nelly Sachs
# 669    http://en.wikipedia.org/wiki/Shmuel_Yosef_Agnon     Shmuel Yosef Agnon
# 645  http://en.wikipedia.org/wiki/Miguel_%C3%81ngel...  Miguel Ángel Asturias
# 631     http://en.wikipedia.org/wiki/Yasunari_Kawabata      Yasunari Kawabata
# 670        http://en.wikipedia.org/wiki/Samuel_Beckett         Samuel Beckett
#
#      year    category                  country  \
# 778  1960  Literature                   France
# 33   1962  Literature            United States
# 724  1963  Literature                   Greece
# 777  1964  Literature                   France
# 577  1965  Literature  Russia and Soviet Union
# 543  1966  Literature                   Sweden
# 669  1966  Literature                   Israel
# 645  1967  Literature                Guatemala
# 631  1968  Literature                    Japan
# 670  1969  Literature                  Ireland
#
#                                                   text date_of_birth  \
# 778                Saint-John Perse , Literature, 1960    1887-05-31
# 33                   John Steinbeck , Literature, 1962    1902-02-27
# 724                 Giorgos Seferis , Literature, 1963    1900-03-13
# 777  Jean-Paul Sartre , Literature, 1964 (declined ...    1905-06-21
# 577               Mikhail Sholokhov , Literature, 1965    1905-05-11
# 543  Nelly Sachs ,  born in Germany , Literature, 1966    1891-12-10
# 669  Shmuel Yosef Agnon ,  born in  Austria-Hungary...    1888-07-17
# 645           Miguel Ángel Asturias , Literature, 1967    1899-10-19
# 631               Yasunari Kawabata , Literature, 1968    1899-06-11
# 670                  Samuel Beckett , Literature, 1969    1906-04-13
#
#     date_of_death     place_of_birth                place_of_death  gender  \
# 778    1975-09-20     Pointe-à-Pitre                        Hyères    male
# 33     1968-12-20            Salinas                        Harlem    male
# 724    1971-09-20              İzmir                        Athens    male
# 777    1980-04-15              Paris  14th arrondissement of Paris    male
# 577    1984-02-21          Kruzhilin                  Vyoshenskaya    male
# 543    1970-05-12  Berlin-Schöneberg                     Stockholm  female
# 669    1970-02-17            Buchach                     Jerusalem    male
# 645    1974-06-09     Guatemala City                        Madrid    male
# 631    1972-04-16              Ōsaka                         Zushi    male
# 670    1989-12-22             Dublin                         Paris    male
#
#      award_age
# 778         73
# 33          60
# 724         63
# 777         59
# 577         60
# 543         75
# 669         78
# 645         68
# 631         69
# 670         63

# %%
df[df.name == u'Ivo Andrić']
# kiderült, hogy a fenti Jugoszláv úriember hiányzik, manuális hozzáadjuk az adatsorunkhoz és ezzel az irodalom rendben van
# Out:
# Empty DataFrame
# Columns: [link, name, year, category, country, text, date_of_birth, date_of_death, place_of_birth, place_of_death, gender, award_age]
# Index: []

# %%
data_ivo = {'link': u'http://en.wikipedia.org/wiki/Ivo_Andri%C4%87',  
            'name': u'Ivo Andrić', 
            'year': 1961, 
            'category': 'Literature', 
            'text': u'Ivo Andrić*, born in Condominium of Bosnia and Herzegovina, Austria-Hungary (now Bosnia and Herzegovina), Literature, 1961',
            'country': 'Bosnia and Herzegovina',
            'date_of_birth': pd.to_datetime('9 October 1892'),
            'date_of_death': pd.to_datetime('13 March 1975'),
            'place_of_birth': 'Dolac',
            'place_of_death': 'Belgrade',
            'gender': 'male',
            'award_age': 69
           }

df.append(data_ivo, ignore_index=True)
# Out:
#                                                   link                   name  \
# 0        http://en.wikipedia.org/wiki/Elfriede_Jelinek       Elfriede Jelinek
# 1        http://en.wikipedia.org/wiki/Peter_C._Doherty       Peter C. Doherty
# 2        http://en.wikipedia.org/wiki/Rolf_Zinkernagel       Rolf Zinkernagel
# 3        http://en.wikipedia.org/wiki/Ren%C3%A9_Cassin            René Cassin
# 4           http://en.wikipedia.org/wiki/Isamu_Akasaki          Isamu Akasaki
# ..                                                 ...                    ...
# 922  http://en.wikipedia.org/wiki/Luis_Federico_Leloir   Luis Federico Leloir
# 923      http://en.wikipedia.org/wiki/Bernardo_Houssay       Bernardo Houssay
# 924  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...  Carlos Saavedra Lamas
# 925         http://en.wikipedia.org/wiki/Brian_Schmidt          Brian Schmidt
# 926       http://en.wikipedia.org/wiki/Ivo_Andri%C4%87             Ivo Andrić
#
#      year                category                 country  \
# 0    2004              Literature                 Austria
# 1    1996  Physiology or Medicine               Australia
# 2    1996  Physiology or Medicine               Australia
# 3    1968                   Peace                  France
# 4    2014                 Physics                   Japan
# ..    ...                     ...                     ...
# 922  1970               Chemistry               Argentina
# 923  1947  Physiology or Medicine               Argentina
# 924  1936                   Peace               Argentina
# 925  2011                 Physics               Australia
# 926  1961              Literature  Bosnia and Herzegovina
#
#                                                   text date_of_birth  \
# 0                  Elfriede Jelinek , Literature, 2004    1946-10-20
# 1      Peter C. Doherty , Physiology or Medicine, 1996    1940-10-15
# 2      Rolf Zinkernagel , Physiology or Medicine, 1996    1944-01-06
# 3                            René Cassin , Peace, 1968    1887-02-05
# 4                        Isamu Akasaki , Physics, 2014    1929-01-30
# ..                                                 ...           ...
# 922             Luis Federico Leloir , Chemistry, 1970    1906-09-06
# 923    Bernardo Houssay , Physiology or Medicine, 1947    1887-04-10
# 924                Carlos Saavedra Lamas , Peace, 1936    1878-11-01
# 925  Brian Schmidt ,  born in the United States , P...    1967-02-24
# 926  Ivo Andrić*, born in Condominium of Bosnia and...    1892-10-09
#
#     date_of_death place_of_birth      place_of_death  gender  award_age
# 0             NaT   Mürzzuschlag                 NaN  female         58
# 1             NaT       Brisbane                 NaN    male         56
# 2             NaT         Riehen                 NaN    male         52
# 3      1976-02-20        Bayonne            Istanbul    male         81
# 4             NaT         Chiran                 NaN    male         85
# ..            ...            ...                 ...     ...        ...
# 922    1987-12-02          Paris  Catamarca Province    male         64
# 923    1971-09-21   Buenos Aires        Buenos Aires    male         60
# 924    1959-05-05   Buenos Aires        Buenos Aires    male         58
# 925           NaT       Missoula                 NaN    male         44
# 926    1975-03-13          Dolac            Belgrade    male         69
#
# [927 rows x 12 columns]

# %%
# miután rendben van az irodalom, béke és közgáz Nobel-győztesek sora, megkell nézzük, 
# hogy mi történt az orvostan, kémia és fizikával

count = 0

for i in range(1, 120):
    year = 1900 + i
    
    count = count + int(df[(df.category == 'Physiology or Medicine') & (df.year == year)].count().link)
    
    if not year % 10:
        print('{} = {}'.format(year, count))
        
        count = 0
# Out:
# 1910 = 13
# 1920 = 6
# 1930 = 11
# 1940 = 13
# 1950 = 17
# 1960 = 20
# 1970 = 26
# 1980 = 26
# 1990 = 21
# 2000 = 21
# 2010 = 24

# %%
df[(df.category == 'Physiology or Medicine') & (df.year >= 1921) & (df.year <= 1930)].sort_values(by=['year'])
# Out:
#                                                   link  \
# 389  http://en.wikipedia.org/wiki/Archibald_Vivian_...
# 690   http://en.wikipedia.org/wiki/Otto_Fritz_Meyerhof
# 888  http://en.wikipedia.org/wiki/John_Macleod_(phy...
# 897     http://en.wikipedia.org/wiki/Frederick_Banting
# 617      http://en.wikipedia.org/wiki/Willem_Einthoven
# 787      http://en.wikipedia.org/wiki/Johannes_Fibiger
# 920  http://en.wikipedia.org/wiki/Julius_Wagner-Jau...
# 821       http://en.wikipedia.org/wiki/Charles_Nicolle
# 398     http://en.wikipedia.org/wiki/Frederick_Hopkins
# 619    http://en.wikipedia.org/wiki/Christiaan_Eijkman
# 918      http://en.wikipedia.org/wiki/Karl_Landsteiner
#
#                            name  year                category         country  \
# 389       Archibald Vivian Hill  1922  Physiology or Medicine  United Kingdom
# 690         Otto Fritz Meyerhof  1922  Physiology or Medicine         Germany
# 888  John James Rickard Macleod  1923  Physiology or Medicine          Canada
# 897        Frederick G. Banting  1923  Physiology or Medicine          Canada
# 617            Willem Einthoven  1924  Physiology or Medicine     Netherlands
# 787            Johannes Fibiger  1926  Physiology or Medicine         Denmark
# 920       Julius Wagner-Jauregg  1927  Physiology or Medicine         Austria
# 821             Charles Nicolle  1928  Physiology or Medicine          France
# 398           Frederick Hopkins  1929  Physiology or Medicine  United Kingdom
# 619          Christiaan Eijkman  1929  Physiology or Medicine     Netherlands
# 918            Karl Landsteiner  1930  Physiology or Medicine         Austria
#
#                                                   text date_of_birth  \
# 389  Archibald Vivian Hill , Physiology or Medicine...    1886-09-26
# 690  Otto Fritz Meyerhof , Physiology or Medicine, ...    1884-04-12
# 888  John James Rickard Macleod ,  born in the Unit...    1876-09-06
# 897  Frederick G. Banting , Physiology or Medicine,...    1891-11-14
# 617    Willem Einthoven , Physiology or Medicine, 1924    1860-05-21
# 787    Johannes Fibiger , Physiology or Medicine, 1926    1867-04-23
# 920  Julius Wagner-Jauregg , Physiology or Medicine...    1857-03-07
# 821     Charles Nicolle , Physiology or Medicine, 1928    1866-09-21
# 398   Frederick Hopkins , Physiology or Medicine, 1929    1861-06-20
# 619  Christiaan Eijkman , Physiology or Medicine, 1929    1858-08-11
# 918    Karl Landsteiner , Physiology or Medicine, 1930    1868-06-14
#
#     date_of_death place_of_birth    place_of_death gender  award_age
# 389    1977-06-03        Bristol         Cambridge   male         36
# 690    1951-10-06     Hildesheim      Philadelphia   male         38
# 888    1935-03-16         Clunie          Aberdeen   male         47
# 897    1941-02-21       Alliston  Musgrave Harbour   male         32
# 617    1927-09-29       Semarang            Leiden   male         64
# 787    1928-01-30      Silkeborg        Copenhagen   male         59
# 920    1940-09-27           Wels            Vienna   male         70
# 821    1936-02-28          Rouen             Tunis   male         62
# 398    1947-05-16     Eastbourne         Cambridge   male         68
# 619    1930-11-05        Nijkerk           Utrecht   male         71
# 918    1943-06-26         Vienna     New York City   male         62

# %%
for i in range(0, 120):
    year = 1900 + i
    
    if int(df[(df.category == 'Physiology or Medicine') & (df.year == year)].count().link) >= 2:
        print(year, int(df[(df.category == 'Physiology or Medicine') & (df.year == year)].count().link), sep=' ')
# Out:
# 1906 2
# 1908 3
# 1922 2
# 1923 2
# 1929 2
# 1932 2
# 1934 3
# 1936 2
# 1943 2
# 1944 2
# 1945 3
# 1947 3
# 1949 2
# 1950 3
# 1953 2
# 1954 3
# 1956 4
# 1958 3
# 1959 2
# 1960 2
# 1962 3
# 1963 3
# 1964 2
# 1965 3
# 1966 2
# 1967 3
# 1968 3
# 1969 3
# 1970 3
# 1972 2
# 1973 3
# 1974 3
# 1975 3
# 1976 3
# 1977 3
# 1978 3
# 1979 2
# 1980 3
# 1981 3
# 1982 3
# 1984 2
# 1985 2
# 1986 2
# 1988 3
# 1989 2
# 1990 2
# 1991 2
# 1992 2
# 1993 2
# 1994 2
# 1995 3
# 1996 2
# 1998 3
# 2000 3
# 2001 3
# 2002 3
# 2003 2
# 2004 2
# 2005 2
# 2006 2
# 2007 3
# 2008 3
# 2009 3
# 2011 3
# 2012 2
# 2013 3
# 2014 3
# 2015 3
# 2017 3
# 2018 2
# 2019 3

# %%
df[(df.category == 'Physiology or Medicine') & (df.year == 1956)]
# megvan a második dupla André Frédéric Cournand
df = df[~(df.name == u'André F. Cournand')]

df[(df.category == 'Physiology or Medicine') & (df.year == 1956)]
# Out:
#                                                   link  \
# 95   http://en.wikipedia.org/wiki/Dickinson_W._Rich...
# 764      http://en.wikipedia.org/wiki/Werner_Forssmann
# 780  http://en.wikipedia.org/wiki/Andr%C3%A9_Fr%C3%...
#
#                         name  year                category        country  \
# 95     Dickinson W. Richards  1956  Physiology or Medicine  United States
# 764         Werner Forssmann  1956  Physiology or Medicine        Germany
# 780  André Frédéric Cournand  1956  Physiology or Medicine         France
#
#                                                   text date_of_birth  \
# 95   Dickinson W. Richards , Physiology or Medicine...    1895-10-30
# 764    Werner Forssmann , Physiology or Medicine, 1956    1904-08-29
# 780  André Frédéric Cournand , Physiology or Medici...    1895-09-24
#
#     date_of_death place_of_birth     place_of_death gender  award_age
# 95     1973-02-23         Orange  Litchfield County   male         61
# 764    1979-06-01         Berlin         Schopfheim   male         52
# 780    1988-02-19          Paris   Great Barrington   male         61

# %%
# tehát mostmár megvan oldva minden, kivétel a fizika és kémia
# időközben kiderült, hogy van egy orvostan győztesem, aki valamely Nobel-listán szerepel, de a hivatalos például nem
# de bennehagyom, hiszen ő is nyertes volt 1908-ban
# Out:
# link              925
# name              925
# year              925
# category          925
# country           925
# text              925
# date_of_birth     925
# date_of_death     632
# place_of_birth    925
# place_of_death    632
# gender            925
# award_age         925
# dtype: int64

# %%
for i in range(0, 120):
    year = 1900 + i
    
    if int(df[(df.category == 'Physics') & (df.year == year)].count().link) >= 2:
        print(year, int(df[(df.category == 'Physics') & (df.year == year)].count().link), sep=' ')
# Out:
# 1902 2
# 1903 3
# 1909 2
# 1915 2
# 1925 2
# 1927 2
# 1933 2
# 1936 2
# 1937 2
# 1951 2
# 1952 2
# 1954 2
# 1955 2
# 1956 3
# 1957 2
# 1958 3
# 1959 2
# 1961 2
# 1963 3
# 1964 3
# 1965 3
# 1970 2
# 1972 3
# 1973 3
# 1974 2
# 1975 3
# 1976 2
# 1977 3
# 1978 3
# 1979 3
# 1980 2
# 1981 3
# 1983 2
# 1984 2
# 1986 3
# 1987 2
# 1988 3
# 1989 3
# 1990 3
# 1993 2
# 1994 2
# 1995 2
# 1996 3
# 1997 3
# 1998 3
# 1999 2
# 2000 3
# 2001 3
# 2002 3
# 2003 3
# 2004 3
# 2005 3
# 2006 2
# 2007 2
# 2008 3
# 2009 3
# 2010 2
# 2011 4
# 2012 2
# 2013 2
# 2014 3
# 2015 2
# 2016 3
# 2017 3
# 2018 3
# 2019 3

# %%
df[(df.category == 'Physics') & (df.year == 2011)]
# fizika dupla Brian Schmidt

df = df[~(df.name == 'Brian Schmidt')]

df[(df.category == 'Physics') & (df.year == 2011)]
# Out:
#                                               link              name  year  \
# 337  http://en.wikipedia.org/wiki/Brian_P._Schmidt  Brian P. Schmidt  2011
# 338   http://en.wikipedia.org/wiki/Saul_Perlmutter   Saul Perlmutter  2011
# 339     http://en.wikipedia.org/wiki/Adam_G._Riess     Adam G. Riess  2011
#
#     category        country                              text date_of_birth  \
# 337  Physics  United States  Brian P. Schmidt , Physics, 2011    1967-02-24
# 338  Physics  United States   Saul Perlmutter , Physics, 2011    1959-09-22
# 339  Physics  United States     Adam G. Riess , Physics, 2011    1969-12-16
#
#     date_of_death    place_of_birth place_of_death gender  award_age
# 337           NaT          Missoula            NaN   male         44
# 338           NaT         Champaign            NaN   male         52
# 339           NaT  Washington, D.C.            NaN   male         42

# %%
for i in range(0, 120):
    year = 1900 + i
    
    if int(df[(df.category == 'Chemistry') & (df.year == year)].count().link) >= 2:
        print(year, int(df[(df.category == 'Chemistry') & (df.year == year)].count().link), sep=' ')
# Out:
# 1912 2
# 1929 2
# 1931 2
# 1935 2
# 1937 2
# 1939 2
# 1946 3
# 1950 2
# 1951 2
# 1952 2
# 1956 2
# 1962 2
# 1963 2
# 1967 3
# 1969 2
# 1972 3
# 1973 2
# 1975 2
# 1979 2
# 1980 3
# 1981 2
# 1985 2
# 1986 3
# 1987 3
# 1988 3
# 1989 2
# 1993 2
# 1995 3
# 1996 3
# 1997 3
# 1998 2
# 1999 2
# 2000 3
# 2001 3
# 2002 3
# 2003 2
# 2004 3
# 2005 3
# 2008 3
# 2009 3
# 2010 3
# 2012 2
# 2013 3
# 2014 3
# 2015 3
# 2016 3
# 2017 3
# 2018 3
# 2019 3

# %%
df[df.duplicated(['year', 'date_of_birth'])]

# megvan a duplikátum, Ahmed Zewail
df[(df.category == 'Chemistry') & (df.year == 1999)]
df = df[~(df.name == 'Ahmed Zewail')]
df[(df.category == 'Chemistry') & (df.year == 1999)]
# Out:
#                                              link             name  year  \
# 219  http://en.wikipedia.org/wiki/Ahmed_H._Zewail  Ahmed H. Zewail  1999
#
#       category        country  \
# 219  Chemistry  United States
#
#                                                   text date_of_birth  \
# 219  Ahmed H. Zewail ,  born in Egypt , Chemistry, ...    1946-02-26
#
#     date_of_death place_of_birth place_of_death gender  award_age
# 219    2016-08-02       Damanhur       Pasadena   male         53

# %%
df[df.duplicated(['year', 'date_of_birth'])]
# Out:
#                                                   link              name  \
# 200          http://en.wikipedia.org/wiki/Jerome_Karle      Jerome Karle
# 582  http://en.wikipedia.org/wiki/%C3%89lie_Metchni...  Élie Metchnikoff
# 836          http://en.wikipedia.org/wiki/Yves_Chauvin      Yves Chauvin
#
#      year                category                  country  \
# 200  1985               Chemistry            United States
# 582  1908  Physiology or Medicine  Russia and Soviet Union
# 836  2005               Chemistry                   France
#
#                                                   text date_of_birth  \
# 200                     Jerome Karle , Chemistry, 1985    1918-06-18
# 582  Élie Metchnikoff ,  born in now Ukraine , Phys...    1845-05-03
# 836                     Yves Chauvin , Chemistry, 2005    1930-10-10
#
#     date_of_death place_of_birth place_of_death gender  award_age
# 200    2013-06-06  New York City      Annandale   male         67
# 582    1916-07-02       Ivanivka          Paris   male         63
# 836    2015-01-28          Menen          Tours   male         75

# %%
df[(df.place_of_birth == 'Ivanivka')]
# kiderült, hogy az az ember, aki 1908-ban győztesnek vettem, valójában két néven is "létezik"
# töröljük az egyiket
df = df[~(df.name == u'Élie Metchnikoff')]
df[(df.place_of_birth == 'Ivanivka')]
# Out:
#                                                   link                   name  \
# 422  http://en.wikipedia.org/wiki/Ilya_Ilyich_Mechn...  Ilya Ilyich Mechnikov
#
#      year                category  country  \
# 422  1908  Physiology or Medicine  Ukraine
#
#                                                   text date_of_birth  \
# 422  Ilya Ilyich Mechnikov , Physiology or Medicine...    1845-05-03
#
#     date_of_death place_of_birth place_of_death gender  award_age
# 422    1916-07-02       Ivanivka          Paris   male         63

# %%
df[(df.place_of_death == 'Tours') & (df.year == 2005)]
# Out:
#                                           link          name  year   category  \
# 836  http://en.wikipedia.org/wiki/Yves_Chauvin  Yves Chauvin  2005  Chemistry
#
#     country                            text date_of_birth date_of_death  \
# 836  France  Yves Chauvin , Chemistry, 2005    1930-10-10    2015-01-28
#
#     place_of_birth place_of_death gender  award_age
# 836          Menen          Tours   male         75

# %%
df.describe(include=['object'])
# Out:
#                                             link         name  \
# count                                        922          922
# unique                                       918          918
# top     http://en.wikipedia.org/wiki/Marie_Curie  Marie Curie
# freq                                           2            2
#
#                       category        country                           text  \
# count                      922            922                            922
# unique                       6             59                            922
# top     Physiology or Medicine  United States  Pyotr Kapitsa , Physics, 1978
# freq                       219            362                              1
#
#        place_of_birth place_of_death gender
# count             922            630    922
# unique            648            334      2
# top     New York City      Cambridge   male
# freq               34             35    868

# %%
data_ivo = {'link': u'http://en.wikipedia.org/wiki/Ivo_Andri%C4%87',  
            'name': u'Ivo Andrić', 
            'year': 1961, 
            'category': 'Literature', 
            'text': u'Ivo Andrić*, born in Condominium of Bosnia and Herzegovina, Austria-Hungary (now Bosnia and Herzegovina), Literature, 1961',
            'country': 'Bosnia and Herzegovina',
            'date_of_birth': pd.to_datetime('9 October 1892'),
            'date_of_death': pd.to_datetime('13 March 1975'),
            'place_of_birth': 'Dolac',
            'place_of_death': 'Belgrade',
            'gender': 'male',
            'award_age': 69
           }

df = df.append(data_ivo, ignore_index=True)

# %%
df.describe(include=['object'])
# minden korrekt, 919 egyéni győztes, duplákkal együtt 923, bármilyen egyesület nélkül
df.count()
# Out:
# link              923
# name              923
# year              923
# category          923
# country           923
# text              923
# date_of_birth     923
# date_of_death     631
# place_of_birth    923
# place_of_death    631
# gender            923
# award_age         923
# dtype: int64

# %%
# mostmár fel is tölthetjük a teljes listát, majd kiegészíthetjük Ivo Andric életrajzi adataival a másikat
df = dataframe_mongo_compatible(df)

dataframe_to_mongo(df, 'nobel_prize', 'winners_cleaned', forceupdate=True)

df = dataframe_reverse_compatible(df)

# %%
df_w_bios = mongo_to_dataframe('nobel_prize', 'winners_cleaned_w_bios')

# %%
df = df.reset_index()

df_new = df[['link', 'name', 'category', 'country', 'text', 'place_of_birth', 'place_of_death', 'gender', 'year', 'award_age',\
            'date_of_death', 'date_of_birth']].merge(df_w_bios[['name', 'year', 'image_urls', 'mini_bio', 'bio_image']], on=['name', 'year'], how='left')

ivo_bio = '<p><b>Ivo Andrić</b> (<a href="/wiki/Serbian_Cyrillic_alphabet" title="Serbian Cyrillic alphabet">Serbian Cyrillic</a>: <span lang="sr-Cyrl">Иво Андрић</span>, <small>pronounced&nbsp;</small><span title="Representation in the International Phonetic Alphabet (IPA)" class="IPA"><a href="/wiki/Help:IPA/Serbo-Croatian" title="Help:IPA/Serbo-Croatian">[ǐːʋo ǎːndritɕ]</a></span>; born <b>Ivan Andrić</b>; 9 October 1892&nbsp;– 13 March 1975) was a Yugoslav<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[a]</a></sup> novelist, poet and <a href="/wiki/Short_story" title="Short story">short story</a> writer who won the <a href="/wiki/Nobel_Prize_in_Literature" title="Nobel Prize in Literature">Nobel Prize in Literature</a> in 1961. His writings dealt mainly with life in his native <a href="/wiki/Bosnia_(region)" title="Bosnia (region)">Bosnia</a> under <a href="/wiki/Ottoman_Bosnia_and_Herzegovina" title="Ottoman Bosnia and Herzegovina">Ottoman rule</a>.</p>'\
+ '<p>Born in <a href="/wiki/Travnik" title="Travnik">Travnik</a> in the <a href="/wiki/Austrian_Empire" title="Austrian Empire">Austrian Empire</a>, modern-day <a href="/wiki/Bosnia" class="mw-redirect" title="Bosnia">Bosnia</a>, Andrić attended high school in <a href="/wiki/Sarajevo" title="Sarajevo">Sarajevo</a>, where he became an active member of several <a href="/wiki/South_Slavs" title="South Slavs">South Slav</a> national youth organizations. Following the <a href="/wiki/Assassination_of_Archduke_Franz_Ferdinand_of_Austria" class="mw-redirect" title="Assassination of Archduke Franz Ferdinand of Austria">assassination</a> of Archduke <a href="/wiki/Archduke_Franz_Ferdinand_of_Austria" title="Archduke Franz Ferdinand of Austria">Franz Ferdinand</a> in June 1914, Andrić was arrested and imprisoned by the Austro-Hungarian police, who suspected his involvement in the plot. As the authorities were unable to build a strong case against him, he spent much of the war under <a href="/wiki/House_arrest" title="House arrest">house arrest</a>, only being released following a general amnesty for such cases in July 1917. After the war, he studied South Slavic history and literature at universities in <a href="/wiki/Zagreb" title="Zagreb">Zagreb</a> and <a href="/wiki/Graz" title="Graz">Graz</a>, eventually attaining his <a href="/wiki/Doctor_of_Philosophy" title="Doctor of Philosophy">Ph.D</a>. in Graz in 1924. He worked in the diplomatic service of the <a href="/wiki/Kingdom_of_Yugoslavia" title="Kingdom of Yugoslavia">Kingdom of Yugoslavia</a> from 1920 to 1923 and again from 1924 to 1941. In 1939, he became Yugoslavia\'s ambassador to <a href="/wiki/Nazi_Germany" title="Nazi Germany">Germany</a>, but his tenure ended in April 1941 with the <a href="/wiki/Invasion_of_Yugoslavia" title="Invasion of Yugoslavia">German-led invasion of his country</a>. Shortly after the invasion, Andrić returned to German-occupied <a href="/wiki/Belgrade" title="Belgrade">Belgrade</a>. He lived quietly in a friend\'s apartment for the duration of World War II, in conditions likened by some biographers to house arrest, and wrote some of his most important works, including <i><a href="/wiki/The_Bridge_on_the_Drina" title="The Bridge on the Drina">Na Drini ćuprija</a></i> (<i>The Bridge on the Drina</i>).</p>'\
+ '<p>Following the war, Andrić was named to a number of ceremonial posts in Yugoslavia, which had since come under communist rule. In 1961, the <a href="/wiki/Nobel_Committee" title="Nobel Committee">Nobel Committee</a> awarded him the Nobel Prize in Literature, selecting him over writers such as <a href="/wiki/J._R._R._Tolkien" title="J. R. R. Tolkien">J. R. R. Tolkien</a>, <a href="/wiki/Robert_Frost" title="Robert Frost">Robert Frost</a>, <a href="/wiki/John_Steinbeck" title="John Steinbeck">John Steinbeck</a> and <a href="/wiki/E._M._Forster" title="E. M. Forster">E. M. Forster</a>. The Committee cited "the epic force with which he&nbsp;... traced themes and depicted human destinies drawn from his country\'s history". Afterwards, Andrić\'s works found an international audience and were translated into a number of languages. In subsequent years, he received a number of awards in his native country. Andrić\'s health declined substantially in late 1974 and he died in Belgrade the following March.</p>'\
+ '<p>In the years following Andrić\'s death, the Belgrade apartment where he spent much of World War II was converted into a museum and a nearby street corner was named in his honour. A number of other cities in the former <a href="/wiki/Yugoslavia" title="Yugoslavia">Yugoslavia</a> also have streets bearing his name. In 2012, filmmaker <a href="/wiki/Emir_Kusturica" title="Emir Kusturica">Emir Kusturica</a> began construction of an ethno-town in eastern Bosnia that is <a href="/wiki/Andri%C4%87grad" title="Andrićgrad">named after Andrić</a>. As Yugoslavia\'s only Nobel Prize-winning writer, Andrić was well known and respected in his native country during his lifetime. In Bosnia and Herzegovina, beginning in the 1950s and continuing past the <a href="/wiki/Breakup_of_Yugoslavia" title="Breakup of Yugoslavia">breakup of Yugoslavia</a>, his works have been disparaged by Bosniak literary critics for their supposed anti-Muslim bias. In Croatia, his works were long shunned for nationalist reasons, and even briefly blacklisted following Yugoslavia\'s dissolution, but were rehabilitated by the literary community at the start of the 21st century. He is highly regarded in Serbia for his contributions to <a href="/wiki/Serbian_literature" title="Serbian literature">Serbian literature</a>.</p>'

# %%
df_new = df_new.set_index('name')
df_new
# Out:
#                                                                     link  \
# name
# Elfriede Jelinek           http://en.wikipedia.org/wiki/Elfriede_Jelinek
# Peter C. Doherty           http://en.wikipedia.org/wiki/Peter_C._Doherty
# Rolf Zinkernagel           http://en.wikipedia.org/wiki/Rolf_Zinkernagel
# René Cassin                http://en.wikipedia.org/wiki/Ren%C3%A9_Cassin
# Isamu Akasaki                 http://en.wikipedia.org/wiki/Isamu_Akasaki
# ...                                                                  ...
# Adolfo Pérez Esquivel  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...
# Luis Federico Leloir   http://en.wikipedia.org/wiki/Luis_Federico_Leloir
# Bernardo Houssay           http://en.wikipedia.org/wiki/Bernardo_Houssay
# Carlos Saavedra Lamas  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...
# Ivo Andrić                  http://en.wikipedia.org/wiki/Ivo_Andri%C4%87
#
#                                      category                 country  \
# name
# Elfriede Jelinek                   Literature                 Austria
# Peter C. Doherty       Physiology or Medicine               Australia
# Rolf Zinkernagel       Physiology or Medicine               Australia
# René Cassin                             Peace                  France
# Isamu Akasaki                         Physics                   Japan
# ...                                       ...                     ...
# Adolfo Pérez Esquivel                   Peace               Argentina
# Luis Federico Leloir                Chemistry               Argentina
# Bernardo Houssay       Physiology or Medicine               Argentina
# Carlos Saavedra Lamas                   Peace               Argentina
# Ivo Andrić                         Literature  Bosnia and Herzegovina
#
#                                                                     text  \
# name
# Elfriede Jelinek                     Elfriede Jelinek , Literature, 2004
# Peter C. Doherty         Peter C. Doherty , Physiology or Medicine, 1996
# Rolf Zinkernagel         Rolf Zinkernagel , Physiology or Medicine, 1996
# René Cassin                                    René Cassin , Peace, 1968
# Isamu Akasaki                              Isamu Akasaki , Physics, 2014
# ...                                                                  ...
# Adolfo Pérez Esquivel                Adolfo Pérez Esquivel , Peace, 1980
# Luis Federico Leloir              Luis Federico Leloir , Chemistry, 1970
# Bernardo Houssay         Bernardo Houssay , Physiology or Medicine, 1947
# Carlos Saavedra Lamas                Carlos Saavedra Lamas , Peace, 1936
# Ivo Andrić             Ivo Andrić*, born in Condominium of Bosnia and...
#
#                       place_of_birth      place_of_death  gender  year  \
# name
# Elfriede Jelinek        Mürzzuschlag                 NaN  female  2004
# Peter C. Doherty            Brisbane                 NaN    male  1996
# Rolf Zinkernagel              Riehen                 NaN    male  1996
# René Cassin                  Bayonne            Istanbul    male  1968
# Isamu Akasaki                 Chiran                 NaN    male  2014
# ...                              ...                 ...     ...   ...
# Adolfo Pérez Esquivel   Buenos Aires                 NaN    male  1980
# Luis Federico Leloir           Paris  Catamarca Province    male  1970
# Bernardo Houssay        Buenos Aires        Buenos Aires    male  1947
# Carlos Saavedra Lamas   Buenos Aires        Buenos Aires    male  1936
# Ivo Andrić                     Dolac            Belgrade    male  1961
#
#                        award_age date_of_death date_of_birth  \
# name
# Elfriede Jelinek              58           NaT    1946-10-20
# Peter C. Doherty              56           NaT    1940-10-15
# Rolf Zinkernagel              52           NaT    1944-01-06
# René Cassin                   81    1976-02-20    1887-02-05
# Isamu Akasaki                 85           NaT    1929-01-30
# ...                          ...           ...           ...
# Adolfo Pérez Esquivel         49           NaT    1931-11-26
# Luis Federico Leloir          64    1987-12-02    1906-09-06
# Bernardo Houssay              60    1971-09-21    1887-04-10
# Carlos Saavedra Lamas         58    1959-05-05    1878-11-01
# Ivo Andrić                    69    1975-03-13    1892-10-09
#
#                                                               image_urls  \
# name
# Elfriede Jelinek       [https://upload.wikimedia.org/wikipedia/common...
# Peter C. Doherty       [https://upload.wikimedia.org/wikipedia/common...
# Rolf Zinkernagel       [https://upload.wikimedia.org/wikipedia/common...
# René Cassin            [https://upload.wikimedia.org/wikipedia/common...
# Isamu Akasaki                                                        NaN
# ...                                                                  ...
# Adolfo Pérez Esquivel  [https://upload.wikimedia.org/wikipedia/common...
# Luis Federico Leloir   [https://upload.wikimedia.org/wikipedia/common...
# Bernardo Houssay                                                     NaN
# Carlos Saavedra Lamas  [https://upload.wikimedia.org/wikipedia/common...
# Ivo Andrić                                                           NaN
#
#                                                                 mini_bio  \
# name
# Elfriede Jelinek       <p><b>Elfriede Jelinek</b> (<small>German: </s...
# Peter C. Doherty       <p><b>Peter Charles Doherty</b>, <span class="...
# Rolf Zinkernagel       <p><b>Rolf Martin Zinkernagel</b> <span class=...
# René Cassin            <p><b>René Samuel Cassin</b> (5 October 1887 –...
# Isamu Akasaki          <p><b>Isamu Akasaki</b><span style="font-weigh...
# ...                                                                  ...
# Adolfo Pérez Esquivel  <p><b>Adolfo Pérez Esquivel</b> (born November...
# Luis Federico Leloir   <p><b>Luis Federico Leloir</b> <span class="no...
# Bernardo Houssay       <p><b>Bernardo Alberto Houssay</b> (April 10, ...
# Carlos Saavedra Lamas  <p><b>Carlos Saavedra Lamas</b> (November 1, 1...
# Ivo Andrić                                                           NaN
#
#                                                                bio_image
# name
# Elfriede Jelinek       full/2ce212a3d7d17ad40edb43ba51c4d5edabbee352.jpg
# Peter C. Doherty       full/3e0467061b4cabf7a60f238b9d51a8017c7c5122.jpg
# Rolf Zinkernagel       full/0ddaff54c8cc90cbe3018431ef0a87e3189ed161.jpg
# René Cassin            full/e08694de28d166c0fedff0c856820c25927b2751.jpg
# Isamu Akasaki                                                       None
# ...                                                                  ...
# Adolfo Pérez Esquivel  full/fda863143ba4f92d64d3349dff90aabe86305823.jpg
# Luis Federico Leloir   full/7f20974a211572c3ba715d69412da998466b32e7.jpg
# Bernardo Houssay                                                    None
# Carlos Saavedra Lamas  full/dfe7bd81cfe9c364f1d2ed94625c2e8ecd1530ac.jpg
# Ivo Andrić                                                           NaN
#
# [923 rows x 14 columns]

# %%
df_new.loc[u'Ivo Andrić', 'mini_bio'] = ivo_bio
df_new.loc[u'Ivo Andrić', 'mini_bio']
# Out:
# '<p><b>Ivo Andrić</b> (<a href="/wiki/Serbian_Cyrillic_alphabet" title="Serbian Cyrillic alphabet">Serbian Cyrillic</a>: <span lang="sr-Cyrl">Иво Андрић</span>, <small>pronounced&nbsp;</small><span title="Representation in the International Phonetic Alphabet (IPA)" class="IPA"><a href="/wiki/Help:IPA/Serbo-Croatian" title="Help:IPA/Serbo-Croatian">[ǐːʋo ǎːndritɕ]</a></span>; born <b>Ivan Andrić</b>; 9 October 1892&nbsp;– 13 March 1975) was a Yugoslav<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[a]</a></sup> novelist, poet and <a href="/wiki/Short_story" title="Short story">short story</a> writer who won the <a href="/wiki/Nobel_Prize_in_Literature" title="Nobel Prize in Literature">Nobel Prize in Literature</a> in 1961. His writings dealt mainly with life in his native <a href="/wiki/Bosnia_(region)" title="Bosnia (region)">Bosnia</a> under <a href="/wiki/Ottoman_Bosnia_and_Herzegovina" title="Ottoman Bosnia and Herzegovina">Ottoman rule</a>.</p><p>Born in <a href="/wiki/Travnik" title="Travnik">Travnik</a> in the <a href="/wiki/Austrian_Empire" title="Austrian Empire">Austrian Empire</a>, modern-day <a href="/wiki/Bosnia" class="mw-redirect" title="Bosnia">Bosnia</a>, Andrić attended high school in <a href="/wiki/Sarajevo" title="Sarajevo">Sarajevo</a>, where he became an active member of several <a href="/wiki/South_Slavs" title="South Slavs">South Slav</a> national youth organizations. Following the <a href="/wiki/Assassination_of_Archduke_Franz_Ferdinand_of_Austria" class="mw-redirect" title="Assassination of Archduke Franz Ferdinand of Austria">assassination</a> of Archduke <a href="/wiki/Archduke_Franz_Ferdinand_of_Austria" title="Archduke Franz Ferdinand of Austria">Franz Ferdinand</a> in June 1914, Andrić was arrested and imprisoned by the Austro-Hungarian police, who suspected his involvement in the plot. As the authorities were unable to build a strong case against him, he spent much of the war under <a href="/wiki/House_arrest" title="House arrest">house arrest</a>, only being released following a general amnesty for such cases in July 1917. After the war, he studied South Slavic history and literature at universities in <a href="/wiki/Zagreb" title="Zagreb">Zagreb</a> and <a href="/wiki/Graz" title="Graz">Graz</a>, eventually attaining his <a href="/wiki/Doctor_of_Philosophy" title="Doctor of Philosophy">Ph.D</a>. in Graz in 1924. He worked in the diplomatic service of the <a href="/wiki/Kingdom_of_Yugoslavia" title="Kingdom of Yugoslavia">Kingdom of Yugoslavia</a> from 1920 to 1923 and again from 1924 to 1941. In 1939, he became Yugoslavia\'s ambassador to <a href="/wiki/Nazi_Germany" title="Nazi Germany">Germany</a>, but his tenure ended in April 1941 with the <a href="/wiki/Invasion_of_Yugoslavia" title="Invasion of Yugoslavia">German-led invasion of his country</a>. Shortly after the invasion, Andrić returned to German-occupied <a href="/wiki/Belgrade" title="Belgrade">Belgrade</a>. He lived quietly in a friend\'s apartment for the duration of World War II, in conditions likened by some biographers to house arrest, and wrote some of his most important works, including <i><a href="/wiki/The_Bridge_on_the_Drina" title="The Bridge on the Drina">Na Drini ćuprija</a></i> (<i>The Bridge on the Drina</i>).</p><p>Following the war, Andrić was named to a number of ceremonial posts in Yugoslavia, which had since come under communist rule. In 1961, the <a href="/wiki/Nobel_Committee" title="Nobel Committee">Nobel Committee</a> awarded him the Nobel Prize in Literature, selecting him over writers such as <a href="/wiki/J._R._R._Tolkien" title="J. R. R. Tolkien">J. R. R. Tolkien</a>, <a href="/wiki/Robert_Frost" title="Robert Frost">Robert Frost</a>, <a href="/wiki/John_Steinbeck" title="John Steinbeck">John Steinbeck</a> and <a href="/wiki/E._M._Forster" title="E. M. Forster">E. M. Forster</a>. The Committee cited "the epic force with which he&nbsp;... traced themes and depicted human destinies drawn from  ...

# %%
df_new
# Out:
#                                                                     link  \
# name
# Elfriede Jelinek           http://en.wikipedia.org/wiki/Elfriede_Jelinek
# Peter C. Doherty           http://en.wikipedia.org/wiki/Peter_C._Doherty
# Rolf Zinkernagel           http://en.wikipedia.org/wiki/Rolf_Zinkernagel
# René Cassin                http://en.wikipedia.org/wiki/Ren%C3%A9_Cassin
# Isamu Akasaki                 http://en.wikipedia.org/wiki/Isamu_Akasaki
# ...                                                                  ...
# Adolfo Pérez Esquivel  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...
# Luis Federico Leloir   http://en.wikipedia.org/wiki/Luis_Federico_Leloir
# Bernardo Houssay           http://en.wikipedia.org/wiki/Bernardo_Houssay
# Carlos Saavedra Lamas  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...
# Ivo Andrić                  http://en.wikipedia.org/wiki/Ivo_Andri%C4%87
#
#                                      category                 country  \
# name
# Elfriede Jelinek                   Literature                 Austria
# Peter C. Doherty       Physiology or Medicine               Australia
# Rolf Zinkernagel       Physiology or Medicine               Australia
# René Cassin                             Peace                  France
# Isamu Akasaki                         Physics                   Japan
# ...                                       ...                     ...
# Adolfo Pérez Esquivel                   Peace               Argentina
# Luis Federico Leloir                Chemistry               Argentina
# Bernardo Houssay       Physiology or Medicine               Argentina
# Carlos Saavedra Lamas                   Peace               Argentina
# Ivo Andrić                         Literature  Bosnia and Herzegovina
#
#                                                                     text  \
# name
# Elfriede Jelinek                     Elfriede Jelinek , Literature, 2004
# Peter C. Doherty         Peter C. Doherty , Physiology or Medicine, 1996
# Rolf Zinkernagel         Rolf Zinkernagel , Physiology or Medicine, 1996
# René Cassin                                    René Cassin , Peace, 1968
# Isamu Akasaki                              Isamu Akasaki , Physics, 2014
# ...                                                                  ...
# Adolfo Pérez Esquivel                Adolfo Pérez Esquivel , Peace, 1980
# Luis Federico Leloir              Luis Federico Leloir , Chemistry, 1970
# Bernardo Houssay         Bernardo Houssay , Physiology or Medicine, 1947
# Carlos Saavedra Lamas                Carlos Saavedra Lamas , Peace, 1936
# Ivo Andrić             Ivo Andrić*, born in Condominium of Bosnia and...
#
#                       place_of_birth      place_of_death  gender  year  \
# name
# Elfriede Jelinek        Mürzzuschlag                 NaN  female  2004
# Peter C. Doherty            Brisbane                 NaN    male  1996
# Rolf Zinkernagel              Riehen                 NaN    male  1996
# René Cassin                  Bayonne            Istanbul    male  1968
# Isamu Akasaki                 Chiran                 NaN    male  2014
# ...                              ...                 ...     ...   ...
# Adolfo Pérez Esquivel   Buenos Aires                 NaN    male  1980
# Luis Federico Leloir           Paris  Catamarca Province    male  1970
# Bernardo Houssay        Buenos Aires        Buenos Aires    male  1947
# Carlos Saavedra Lamas   Buenos Aires        Buenos Aires    male  1936
# Ivo Andrić                     Dolac            Belgrade    male  1961
#
#                        award_age date_of_death date_of_birth  \
# name
# Elfriede Jelinek              58           NaT    1946-10-20
# Peter C. Doherty              56           NaT    1940-10-15
# Rolf Zinkernagel              52           NaT    1944-01-06
# René Cassin                   81    1976-02-20    1887-02-05
# Isamu Akasaki                 85           NaT    1929-01-30
# ...                          ...           ...           ...
# Adolfo Pérez Esquivel         49           NaT    1931-11-26
# Luis Federico Leloir          64    1987-12-02    1906-09-06
# Bernardo Houssay              60    1971-09-21    1887-04-10
# Carlos Saavedra Lamas         58    1959-05-05    1878-11-01
# Ivo Andrić                    69    1975-03-13    1892-10-09
#
#                                                               image_urls  \
# name
# Elfriede Jelinek       [https://upload.wikimedia.org/wikipedia/common...
# Peter C. Doherty       [https://upload.wikimedia.org/wikipedia/common...
# Rolf Zinkernagel       [https://upload.wikimedia.org/wikipedia/common...
# René Cassin            [https://upload.wikimedia.org/wikipedia/common...
# Isamu Akasaki                                                        NaN
# ...                                                                  ...
# Adolfo Pérez Esquivel  [https://upload.wikimedia.org/wikipedia/common...
# Luis Federico Leloir   [https://upload.wikimedia.org/wikipedia/common...
# Bernardo Houssay                                                     NaN
# Carlos Saavedra Lamas  [https://upload.wikimedia.org/wikipedia/common...
# Ivo Andrić                                                           NaN
#
#                                                                 mini_bio  \
# name
# Elfriede Jelinek       <p><b>Elfriede Jelinek</b> (<small>German: </s...
# Peter C. Doherty       <p><b>Peter Charles Doherty</b>, <span class="...
# Rolf Zinkernagel       <p><b>Rolf Martin Zinkernagel</b> <span class=...
# René Cassin            <p><b>René Samuel Cassin</b> (5 October 1887 –...
# Isamu Akasaki          <p><b>Isamu Akasaki</b><span style="font-weigh...
# ...                                                                  ...
# Adolfo Pérez Esquivel  <p><b>Adolfo Pérez Esquivel</b> (born November...
# Luis Federico Leloir   <p><b>Luis Federico Leloir</b> <span class="no...
# Bernardo Houssay       <p><b>Bernardo Alberto Houssay</b> (April 10, ...
# Carlos Saavedra Lamas  <p><b>Carlos Saavedra Lamas</b> (November 1, 1...
# Ivo Andrić             <p><b>Ivo Andrić</b> (<a href="/wiki/Serbian_C...
#
#                                                                bio_image
# name
# Elfriede Jelinek       full/2ce212a3d7d17ad40edb43ba51c4d5edabbee352.jpg
# Peter C. Doherty       full/3e0467061b4cabf7a60f238b9d51a8017c7c5122.jpg
# Rolf Zinkernagel       full/0ddaff54c8cc90cbe3018431ef0a87e3189ed161.jpg
# René Cassin            full/e08694de28d166c0fedff0c856820c25927b2751.jpg
# Isamu Akasaki                                                       None
# ...                                                                  ...
# Adolfo Pérez Esquivel  full/fda863143ba4f92d64d3349dff90aabe86305823.jpg
# Luis Federico Leloir   full/7f20974a211572c3ba715d69412da998466b32e7.jpg
# Bernardo Houssay                                                    None
# Carlos Saavedra Lamas  full/dfe7bd81cfe9c364f1d2ed94625c2e8ecd1530ac.jpg
# Ivo Andrić                                                           NaN
#
# [923 rows x 14 columns]

# %%
df_new.loc[u'Ivo Andrić', 'bio_image'] = None

# %%
df_new
# Out:
#                                                                     link  \
# name
# Elfriede Jelinek           http://en.wikipedia.org/wiki/Elfriede_Jelinek
# Peter C. Doherty           http://en.wikipedia.org/wiki/Peter_C._Doherty
# Rolf Zinkernagel           http://en.wikipedia.org/wiki/Rolf_Zinkernagel
# René Cassin                http://en.wikipedia.org/wiki/Ren%C3%A9_Cassin
# Isamu Akasaki                 http://en.wikipedia.org/wiki/Isamu_Akasaki
# ...                                                                  ...
# Adolfo Pérez Esquivel  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...
# Luis Federico Leloir   http://en.wikipedia.org/wiki/Luis_Federico_Leloir
# Bernardo Houssay           http://en.wikipedia.org/wiki/Bernardo_Houssay
# Carlos Saavedra Lamas  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...
# Ivo Andrić                  http://en.wikipedia.org/wiki/Ivo_Andri%C4%87
#
#                                      category                 country  \
# name
# Elfriede Jelinek                   Literature                 Austria
# Peter C. Doherty       Physiology or Medicine               Australia
# Rolf Zinkernagel       Physiology or Medicine               Australia
# René Cassin                             Peace                  France
# Isamu Akasaki                         Physics                   Japan
# ...                                       ...                     ...
# Adolfo Pérez Esquivel                   Peace               Argentina
# Luis Federico Leloir                Chemistry               Argentina
# Bernardo Houssay       Physiology or Medicine               Argentina
# Carlos Saavedra Lamas                   Peace               Argentina
# Ivo Andrić                         Literature  Bosnia and Herzegovina
#
#                                                                     text  \
# name
# Elfriede Jelinek                     Elfriede Jelinek , Literature, 2004
# Peter C. Doherty         Peter C. Doherty , Physiology or Medicine, 1996
# Rolf Zinkernagel         Rolf Zinkernagel , Physiology or Medicine, 1996
# René Cassin                                    René Cassin , Peace, 1968
# Isamu Akasaki                              Isamu Akasaki , Physics, 2014
# ...                                                                  ...
# Adolfo Pérez Esquivel                Adolfo Pérez Esquivel , Peace, 1980
# Luis Federico Leloir              Luis Federico Leloir , Chemistry, 1970
# Bernardo Houssay         Bernardo Houssay , Physiology or Medicine, 1947
# Carlos Saavedra Lamas                Carlos Saavedra Lamas , Peace, 1936
# Ivo Andrić             Ivo Andrić*, born in Condominium of Bosnia and...
#
#                       place_of_birth      place_of_death  gender  year  \
# name
# Elfriede Jelinek        Mürzzuschlag                 NaN  female  2004
# Peter C. Doherty            Brisbane                 NaN    male  1996
# Rolf Zinkernagel              Riehen                 NaN    male  1996
# René Cassin                  Bayonne            Istanbul    male  1968
# Isamu Akasaki                 Chiran                 NaN    male  2014
# ...                              ...                 ...     ...   ...
# Adolfo Pérez Esquivel   Buenos Aires                 NaN    male  1980
# Luis Federico Leloir           Paris  Catamarca Province    male  1970
# Bernardo Houssay        Buenos Aires        Buenos Aires    male  1947
# Carlos Saavedra Lamas   Buenos Aires        Buenos Aires    male  1936
# Ivo Andrić                     Dolac            Belgrade    male  1961
#
#                        award_age date_of_death date_of_birth  \
# name
# Elfriede Jelinek              58           NaT    1946-10-20
# Peter C. Doherty              56           NaT    1940-10-15
# Rolf Zinkernagel              52           NaT    1944-01-06
# René Cassin                   81    1976-02-20    1887-02-05
# Isamu Akasaki                 85           NaT    1929-01-30
# ...                          ...           ...           ...
# Adolfo Pérez Esquivel         49           NaT    1931-11-26
# Luis Federico Leloir          64    1987-12-02    1906-09-06
# Bernardo Houssay              60    1971-09-21    1887-04-10
# Carlos Saavedra Lamas         58    1959-05-05    1878-11-01
# Ivo Andrić                    69    1975-03-13    1892-10-09
#
#                                                               image_urls  \
# name
# Elfriede Jelinek       [https://upload.wikimedia.org/wikipedia/common...
# Peter C. Doherty       [https://upload.wikimedia.org/wikipedia/common...
# Rolf Zinkernagel       [https://upload.wikimedia.org/wikipedia/common...
# René Cassin            [https://upload.wikimedia.org/wikipedia/common...
# Isamu Akasaki                                                        NaN
# ...                                                                  ...
# Adolfo Pérez Esquivel  [https://upload.wikimedia.org/wikipedia/common...
# Luis Federico Leloir   [https://upload.wikimedia.org/wikipedia/common...
# Bernardo Houssay                                                     NaN
# Carlos Saavedra Lamas  [https://upload.wikimedia.org/wikipedia/common...
# Ivo Andrić                                                           NaN
#
#                                                                 mini_bio  \
# name
# Elfriede Jelinek       <p><b>Elfriede Jelinek</b> (<small>German: </s...
# Peter C. Doherty       <p><b>Peter Charles Doherty</b>, <span class="...
# Rolf Zinkernagel       <p><b>Rolf Martin Zinkernagel</b> <span class=...
# René Cassin            <p><b>René Samuel Cassin</b> (5 October 1887 –...
# Isamu Akasaki          <p><b>Isamu Akasaki</b><span style="font-weigh...
# ...                                                                  ...
# Adolfo Pérez Esquivel  <p><b>Adolfo Pérez Esquivel</b> (born November...
# Luis Federico Leloir   <p><b>Luis Federico Leloir</b> <span class="no...
# Bernardo Houssay       <p><b>Bernardo Alberto Houssay</b> (April 10, ...
# Carlos Saavedra Lamas  <p><b>Carlos Saavedra Lamas</b> (November 1, 1...
# Ivo Andrić             <p><b>Ivo Andrić</b> (<a href="/wiki/Serbian_C...
#
#                                                                bio_image
# name
# Elfriede Jelinek       full/2ce212a3d7d17ad40edb43ba51c4d5edabbee352.jpg
# Peter C. Doherty       full/3e0467061b4cabf7a60f238b9d51a8017c7c5122.jpg
# Rolf Zinkernagel       full/0ddaff54c8cc90cbe3018431ef0a87e3189ed161.jpg
# René Cassin            full/e08694de28d166c0fedff0c856820c25927b2751.jpg
# Isamu Akasaki                                                       None
# ...                                                                  ...
# Adolfo Pérez Esquivel  full/fda863143ba4f92d64d3349dff90aabe86305823.jpg
# Luis Federico Leloir   full/7f20974a211572c3ba715d69412da998466b32e7.jpg
# Bernardo Houssay                                                    None
# Carlos Saavedra Lamas  full/dfe7bd81cfe9c364f1d2ed94625c2e8ecd1530ac.jpg
# Ivo Andrić                                                          None
#
# [923 rows x 14 columns]

# %%
df_new = df_new.reset_index()
df_new
# Out:
#                       name                                               link  \
# 0         Elfriede Jelinek      http://en.wikipedia.org/wiki/Elfriede_Jelinek
# 1         Peter C. Doherty      http://en.wikipedia.org/wiki/Peter_C._Doherty
# 2         Rolf Zinkernagel      http://en.wikipedia.org/wiki/Rolf_Zinkernagel
# 3              René Cassin      http://en.wikipedia.org/wiki/Ren%C3%A9_Cassin
# 4            Isamu Akasaki         http://en.wikipedia.org/wiki/Isamu_Akasaki
# ..                     ...                                                ...
# 918  Adolfo Pérez Esquivel  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...
# 919   Luis Federico Leloir  http://en.wikipedia.org/wiki/Luis_Federico_Leloir
# 920       Bernardo Houssay      http://en.wikipedia.org/wiki/Bernardo_Houssay
# 921  Carlos Saavedra Lamas  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...
# 922             Ivo Andrić       http://en.wikipedia.org/wiki/Ivo_Andri%C4%87
#
#                    category                 country  \
# 0                Literature                 Austria
# 1    Physiology or Medicine               Australia
# 2    Physiology or Medicine               Australia
# 3                     Peace                  France
# 4                   Physics                   Japan
# ..                      ...                     ...
# 918                   Peace               Argentina
# 919               Chemistry               Argentina
# 920  Physiology or Medicine               Argentina
# 921                   Peace               Argentina
# 922              Literature  Bosnia and Herzegovina
#
#                                                   text place_of_birth  \
# 0                  Elfriede Jelinek , Literature, 2004   Mürzzuschlag
# 1      Peter C. Doherty , Physiology or Medicine, 1996       Brisbane
# 2      Rolf Zinkernagel , Physiology or Medicine, 1996         Riehen
# 3                            René Cassin , Peace, 1968        Bayonne
# 4                        Isamu Akasaki , Physics, 2014         Chiran
# ..                                                 ...            ...
# 918                Adolfo Pérez Esquivel , Peace, 1980   Buenos Aires
# 919             Luis Federico Leloir , Chemistry, 1970          Paris
# 920    Bernardo Houssay , Physiology or Medicine, 1947   Buenos Aires
# 921                Carlos Saavedra Lamas , Peace, 1936   Buenos Aires
# 922  Ivo Andrić*, born in Condominium of Bosnia and...          Dolac
#
#          place_of_death  gender  year  award_age date_of_death date_of_birth  \
# 0                   NaN  female  2004         58           NaT    1946-10-20
# 1                   NaN    male  1996         56           NaT    1940-10-15
# 2                   NaN    male  1996         52           NaT    1944-01-06
# 3              Istanbul    male  1968         81    1976-02-20    1887-02-05
# 4                   NaN    male  2014         85           NaT    1929-01-30
# ..                  ...     ...   ...        ...           ...           ...
# 918                 NaN    male  1980         49           NaT    1931-11-26
# 919  Catamarca Province    male  1970         64    1987-12-02    1906-09-06
# 920        Buenos Aires    male  1947         60    1971-09-21    1887-04-10
# 921        Buenos Aires    male  1936         58    1959-05-05    1878-11-01
# 922            Belgrade    male  1961         69    1975-03-13    1892-10-09
#
#                                             image_urls  \
# 0    [https://upload.wikimedia.org/wikipedia/common...
# 1    [https://upload.wikimedia.org/wikipedia/common...
# 2    [https://upload.wikimedia.org/wikipedia/common...
# 3    [https://upload.wikimedia.org/wikipedia/common...
# 4                                                  NaN
# ..                                                 ...
# 918  [https://upload.wikimedia.org/wikipedia/common...
# 919  [https://upload.wikimedia.org/wikipedia/common...
# 920                                                NaN
# 921  [https://upload.wikimedia.org/wikipedia/common...
# 922                                                NaN
#
#                                               mini_bio  \
# 0    <p><b>Elfriede Jelinek</b> (<small>German: </s...
# 1    <p><b>Peter Charles Doherty</b>, <span class="...
# 2    <p><b>Rolf Martin Zinkernagel</b> <span class=...
# 3    <p><b>René Samuel Cassin</b> (5 October 1887 –...
# 4    <p><b>Isamu Akasaki</b><span style="font-weigh...
# ..                                                 ...
# 918  <p><b>Adolfo Pérez Esquivel</b> (born November...
# 919  <p><b>Luis Federico Leloir</b> <span class="no...
# 920  <p><b>Bernardo Alberto Houssay</b> (April 10, ...
# 921  <p><b>Carlos Saavedra Lamas</b> (November 1, 1...
# 922  <p><b>Ivo Andrić</b> (<a href="/wiki/Serbian_C...
#
#                                              bio_image
# 0    full/2ce212a3d7d17ad40edb43ba51c4d5edabbee352.jpg
# 1    full/3e0467061b4cabf7a60f238b9d51a8017c7c5122.jpg
# 2    full/0ddaff54c8cc90cbe3018431ef0a87e3189ed161.jpg
# 3    full/e08694de28d166c0fedff0c856820c25927b2751.jpg
# 4                                                 None
# ..                                                 ...
# 918  full/fda863143ba4f92d64d3349dff90aabe86305823.jpg
# 919  full/7f20974a211572c3ba715d69412da998466b32e7.jpg
# 920                                               None
# 921  full/dfe7bd81cfe9c364f1d2ed94625c2e8ecd1530ac.jpg
# 922                                               None
#
# [923 rows x 15 columns]

# %%
# kész, fellehet tölteni a véglegest, és utána leellenőrízni a vizualizációt
df_new = dataframe_mongo_compatible(df_new)

dataframe_to_mongo(df_new, 'nobel_prize', 'winners_cleaned_w_bios', forceupdate=True)

df_new = dataframe_reverse_compatible(df_new)
